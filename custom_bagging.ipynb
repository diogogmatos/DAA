# %%
from preprocessing import preprocess 
from cols_trie import gen_trie

import pandas as pd
import json
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, f1_score

# %%
df_train = pd.read_csv('datasets/train_radiomics_hipocamp.csv')
df_test = pd.read_csv('datasets/test_radiomics_hipocamp.csv')

X,y,le = preprocess(df_train,mode="all")
df_train = pd.concat([X, pd.Series(y.values.ravel(), name='Transition')], axis=1)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Columns: 2013 entries, diagnostics_Image-original_Mean to Age
# dtypes: float64(2013)
# memory usage: 4.7 MB

# %%
cols_trie = gen_trie(X.columns)

important = {"Age", "Sex","diagnostics","Transition"}
target = "Transition"
important_cols = [list(filter(lambda x:x.startswith(g), df_train.columns)) for g in important]
important_cols = [item for sublist in important_cols for item in sublist]
groups = set(cols_trie.keys()) - (important | {target})

grouped = [list(filter(lambda x:x.startswith(g), df_train.columns)) for g in groups]

# %%
dfs = [pd.concat([df_train[g],df_train[list(important_cols)]],axis=1) for g in grouped]
dfs[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 99 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   log-sigma-2-0-mm-3D_firstorder_10Percentile                    305 non-null    float64
#  1   log-sigma-2-0-mm-3D_firstorder_90Percentile                    305 non-null    float64
#  2   log-sigma-2-0-mm-3D_firstorder_Energy                          305 non-null    float64
#  3   log-sigma-2-0-mm-3D_firstorder_Entropy                         305 non-null    float64
#  4   log-sigma-2-0-mm-3D_firstorder_InterquartileRange              305 non-null    float64
#  5   log-sigma-2-0-mm-3D_firstorder_Kurtosis                        305 non-null    float64
#  6   log-sigma-2-0-mm-3D_firstorder_Maximum                         305 non-null    float64
#  7   log-sigma-2-0-mm-3D_firstorder_MeanAbsoluteDeviation           305 non-null    float64
#  8   log-sigma-2-0-mm-3D_firstorder_Mean                            305 non-null    float64
#  9   log-sigma-2-0-mm-3D_firstorder_Median                          305 non-null    float64
#  10  log-sigma-2-0-mm-3D_firstorder_Minimum                         305 non-null    float64
#  11  log-sigma-2-0-mm-3D_firstorder_Range                           305 non-null    float64
#  12  log-sigma-2-0-mm-3D_firstorder_RobustMeanAbsoluteDeviation     305 non-null    float64
#  13  log-sigma-2-0-mm-3D_firstorder_RootMeanSquared                 305 non-null    float64
#  14  log-sigma-2-0-mm-3D_firstorder_Skewness                        305 non-null    float64
#  15  log-sigma-2-0-mm-3D_firstorder_TotalEnergy                     305 non-null    float64
#  16  log-sigma-2-0-mm-3D_firstorder_Uniformity                      305 non-null    float64
#  17  log-sigma-2-0-mm-3D_firstorder_Variance                        305 non-null    float64
#  18  log-sigma-2-0-mm-3D_glcm_Autocorrelation                       305 non-null    float64
#  19  log-sigma-2-0-mm-3D_glcm_ClusterProminence                     305 non-null    float64
#  20  log-sigma-2-0-mm-3D_glcm_ClusterShade                          305 non-null    float64
#  21  log-sigma-2-0-mm-3D_glcm_ClusterTendency                       305 non-null    float64
#  22  log-sigma-2-0-mm-3D_glcm_Contrast                              305 non-null    float64
#  23  log-sigma-2-0-mm-3D_glcm_Correlation                           305 non-null    float64
#  24  log-sigma-2-0-mm-3D_glcm_DifferenceAverage                     305 non-null    float64
#  25  log-sigma-2-0-mm-3D_glcm_DifferenceEntropy                     305 non-null    float64
#  26  log-sigma-2-0-mm-3D_glcm_DifferenceVariance                    305 non-null    float64
#  27  log-sigma-2-0-mm-3D_glcm_Id                                    305 non-null    float64
#  28  log-sigma-2-0-mm-3D_glcm_Idm                                   305 non-null    float64
#  29  log-sigma-2-0-mm-3D_glcm_Idmn                                  305 non-null    float64
#  30  log-sigma-2-0-mm-3D_glcm_Idn                                   305 non-null    float64
#  31  log-sigma-2-0-mm-3D_glcm_Imc1                                  305 non-null    float64
#  32  log-sigma-2-0-mm-3D_glcm_Imc2                                  305 non-null    float64
#  33  log-sigma-2-0-mm-3D_glcm_InverseVariance                       305 non-null    float64
#  34  log-sigma-2-0-mm-3D_glcm_JointAverage                          305 non-null    float64
#  35  log-sigma-2-0-mm-3D_glcm_JointEnergy                           305 non-null    float64
#  36  log-sigma-2-0-mm-3D_glcm_JointEntropy                          305 non-null    float64
#  37  log-sigma-2-0-mm-3D_glcm_MCC                                   305 non-null    float64
#  38  log-sigma-2-0-mm-3D_glcm_MaximumProbability                    305 non-null    float64
#  39  log-sigma-2-0-mm-3D_glcm_SumAverage                            305 non-null    float64
#  40  log-sigma-2-0-mm-3D_glcm_SumEntropy                            305 non-null    float64
#  41  log-sigma-2-0-mm-3D_glcm_SumSquares                            305 non-null    float64
#  42  log-sigma-2-0-mm-3D_gldm_DependenceEntropy                     305 non-null    float64
#  43  log-sigma-2-0-mm-3D_gldm_DependenceNonUniformity               305 non-null    float64
#  44  log-sigma-2-0-mm-3D_gldm_DependenceNonUniformityNormalized     305 non-null    float64
#  45  log-sigma-2-0-mm-3D_gldm_DependenceVariance                    305 non-null    float64
#  46  log-sigma-2-0-mm-3D_gldm_GrayLevelNonUniformity                305 non-null    float64
#  47  log-sigma-2-0-mm-3D_gldm_GrayLevelVariance                     305 non-null    float64
#  48  log-sigma-2-0-mm-3D_gldm_HighGrayLevelEmphasis                 305 non-null    float64
#  49  log-sigma-2-0-mm-3D_gldm_LargeDependenceEmphasis               305 non-null    float64
#  50  log-sigma-2-0-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis  305 non-null    float64
#  51  log-sigma-2-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis   305 non-null    float64
#  52  log-sigma-2-0-mm-3D_gldm_LowGrayLevelEmphasis                  305 non-null    float64
#  53  log-sigma-2-0-mm-3D_gldm_SmallDependenceEmphasis               305 non-null    float64
#  54  log-sigma-2-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis  305 non-null    float64
#  55  log-sigma-2-0-mm-3D_gldm_SmallDependenceLowGrayLevelEmphasis   305 non-null    float64
#  56  log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformity               305 non-null    float64
#  57  log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformityNormalized     305 non-null    float64
#  58  log-sigma-2-0-mm-3D_glrlm_GrayLevelVariance                    305 non-null    float64
#  59  log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis             305 non-null    float64
#  60  log-sigma-2-0-mm-3D_glrlm_LongRunEmphasis                      305 non-null    float64
#  61  log-sigma-2-0-mm-3D_glrlm_LongRunHighGrayLevelEmphasis         305 non-null    float64
#  62  log-sigma-2-0-mm-3D_glrlm_LongRunLowGrayLevelEmphasis          305 non-null    float64
#  63  log-sigma-2-0-mm-3D_glrlm_LowGrayLevelRunEmphasis              305 non-null    float64
#  64  log-sigma-2-0-mm-3D_glrlm_RunEntropy                           305 non-null    float64
#  65  log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformity               305 non-null    float64
#  66  log-sigma-2-0-mm-3D_glrlm_RunLengthNonUniformityNormalized     305 non-null    float64
#  67  log-sigma-2-0-mm-3D_glrlm_RunPercentage                        305 non-null    float64
#  68  log-sigma-2-0-mm-3D_glrlm_RunVariance                          305 non-null    float64
#  69  log-sigma-2-0-mm-3D_glrlm_ShortRunEmphasis                     305 non-null    float64
#  70  log-sigma-2-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis        305 non-null    float64
#  71  log-sigma-2-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis         305 non-null    float64
#  72  log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformity               305 non-null    float64
#  73  log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformityNormalized     305 non-null    float64
#  74  log-sigma-2-0-mm-3D_glszm_GrayLevelVariance                    305 non-null    float64
#  75  log-sigma-2-0-mm-3D_glszm_HighGrayLevelZoneEmphasis            305 non-null    float64
#  76  log-sigma-2-0-mm-3D_glszm_LargeAreaEmphasis                    305 non-null    float64
#  77  log-sigma-2-0-mm-3D_glszm_LargeAreaHighGrayLevelEmphasis       305 non-null    float64
#  78  log-sigma-2-0-mm-3D_glszm_LargeAreaLowGrayLevelEmphasis        305 non-null    float64
#  79  log-sigma-2-0-mm-3D_glszm_LowGrayLevelZoneEmphasis             305 non-null    float64
#  80  log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformity                305 non-null    float64
#  81  log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized      305 non-null    float64
#  82  log-sigma-2-0-mm-3D_glszm_SmallAreaEmphasis                    305 non-null    float64
#  83  log-sigma-2-0-mm-3D_glszm_SmallAreaHighGrayLevelEmphasis       305 non-null    float64
#  84  log-sigma-2-0-mm-3D_glszm_SmallAreaLowGrayLevelEmphasis        305 non-null    float64
#  85  log-sigma-2-0-mm-3D_glszm_ZoneEntropy                          305 non-null    float64
#  86  log-sigma-2-0-mm-3D_glszm_ZonePercentage                       305 non-null    float64
#  87  log-sigma-2-0-mm-3D_glszm_ZoneVariance                         305 non-null    float64
#  88  log-sigma-2-0-mm-3D_ngtdm_Busyness                             305 non-null    float64
#  89  log-sigma-2-0-mm-3D_ngtdm_Coarseness                           305 non-null    float64
#  90  log-sigma-2-0-mm-3D_ngtdm_Complexity                           305 non-null    float64
#  91  log-sigma-2-0-mm-3D_ngtdm_Contrast                             305 non-null    float64
#  92  log-sigma-2-0-mm-3D_ngtdm_Strength                             305 non-null    float64
#  93  Transition                                                     305 non-null    int64
#  94  diagnostics_Image-original_Mean                                305 non-null    float64
#  95  diagnostics_Image-original_Maximum                             305 non-null    float64
#  96  diagnostics_Mask-original_VoxelNum                             305 non-null    float64
#  97  Age                                                            305 non-null    float64
#  98  Sex                                                            305 non-null    float64
# dtypes: float64(98), int64(1)
# memory usage: 236.0 KB

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score,f1_score

def train_svm_voting(df_list, target_column, test_size=0.2, random_state=42):
    classifiers = []
    weights = []
    models = []
    for i, df in enumerate(df_list):
        X = df.drop(columns=[target_column])
        y = df[target_column]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
        
        svm = SVC(
                probability=True,
                random_state=random_state,
                C=5,
                gamma='auto',
                kernel='rbf'
                )
        svm.fit(X_train, y_train)

        y_pred = svm.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='weighted')
        weights.append(f1)
        classifiers.append((f'svm_{i} acc:{accuracy} f1:{f1}', svm))
        models.append({'model':svm,'accuracy':accuracy,'f1':f1,'cols':df.columns})
    # Aggregate results via voting
    voting_clf = VotingClassifier(estimators=classifiers, voting='soft',weights=weights)
    voting_clf.fit(X_train, y_train)
    
    y_pred = voting_clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted') 
    return accuracy,f1,voting_clf,models, weights

_,_,voting_clf,models, _ = train_svm_voting(dfs,target)
m = max(*models,key=lambda x:x['f1'])
m
# Out:
# {'model': SVC(C=5, gamma='auto', probability=True, random_state=42),
#  'accuracy': 0.6065573770491803,
#  'f1': 0.5979655528354835,
#  'cols': Index(['lbp-3D-k_firstorder_10Percentile', 'lbp-3D-k_firstorder_90Percentile',
#         'lbp-3D-k_firstorder_Energy', 'lbp-3D-k_firstorder_Entropy',
#         'lbp-3D-k_firstorder_InterquartileRange',
#         'lbp-3D-k_firstorder_Kurtosis', 'lbp-3D-k_firstorder_Maximum',
#         'lbp-3D-k_firstorder_MeanAbsoluteDeviation', 'lbp-3D-k_firstorder_Mean',
#         'lbp-3D-k_firstorder_Median', 'lbp-3D-k_firstorder_Minimum',
#         'lbp-3D-k_firstorder_Range',
#         'lbp-3D-k_firstorder_RobustMeanAbsoluteDeviation',
#         'lbp-3D-k_firstorder_RootMeanSquared', 'lbp-3D-k_firstorder_Skewness',
#         'lbp-3D-k_firstorder_TotalEnergy', 'lbp-3D-k_firstorder_Uniformity',
#         'lbp-3D-k_firstorder_Variance', 'lbp-3D-k_glcm_Autocorrelation',
#         'lbp-3D-k_glcm_ClusterProminence', 'lbp-3D-k_glcm_ClusterShade',
#         'lbp-3D-k_glcm_ClusterTendency', 'lbp-3D-k_glcm_Contrast',
#         'lbp-3D-k_glcm_Correlation', 'lbp-3D-k_glcm_DifferenceAverage',
#         'lbp-3D-k_glcm_DifferenceEntropy', 'lbp-3D-k_glcm_DifferenceVariance',
#         'lbp-3D-k_glcm_Id', 'lbp-3D-k_glcm_Idm', 'lbp-3D-k_glcm_Idmn',
#         'lbp-3D-k_glcm_Idn', 'lbp-3D-k_glcm_Imc1', 'lbp-3D-k_glcm_Imc2',
#         'lbp-3D-k_glcm_InverseVariance', 'lbp-3D-k_glcm_JointAverage',
#         'lbp-3D-k_glcm_JointEnergy', 'lbp-3D-k_glcm_JointEntropy',
#         'lbp-3D-k_glcm_MCC', 'lbp-3D-k_glcm_MaximumProbability',
#         'lbp-3D-k_glcm_SumAverage', 'lbp-3D-k_glcm_SumEntropy',
#         'lbp-3D-k_glcm_SumSquares', 'lbp-3D-k_gldm_DependenceEntropy',
#         'lbp-3D-k_gldm_DependenceNonUniformity',
#         'lbp-3D-k_gldm_DependenceNonUniformityNormalized',
#         'lbp-3D-k_gldm_DependenceVariance',
#         'lbp-3D-k_gldm_GrayLevelNonUniformity',
#         'lbp-3D-k_gldm_GrayLevelVariance',
#         'lbp-3D-k_gldm_HighGrayLevelEmphasis',
#         'lbp-3D-k_gldm_LargeDependenceEmphasis',
#         'lbp-3D-k_gldm_LargeDependenceHighGrayLevelEmphasis',
#         'lbp-3D-k_gldm_LargeDependenceLowGrayLevelEmphasis',
#         'lbp-3D-k_gldm_LowGrayLevelEmphasis',
#         'lbp-3D-k_gldm_SmallDependenceEmphasis',
#         'lbp-3D-k_gldm_SmallDependenceHighGrayLevelEmphasis',
#         'lbp-3D-k_gldm_SmallDependenceLowGrayLevelEmphasis',
#         'lbp-3D-k_glrlm_GrayLevelNonUniformity',
#         'lbp-3D-k_glrlm_GrayLevelNonUniformityNormalized',
#         'lbp-3D-k_glrlm_GrayLevelVariance',
#         'lbp-3D-k_glrlm_HighGrayLevelRunEmphasis',
#         'lbp-3D-k_glrlm_LongRunEmphasis',
#         'lbp-3D-k_glrlm_LongRunHighGrayLevelEmphasis',
#         'lbp-3D-k_glrlm_LongRunLowGrayLevelEmphasis',
#         'lbp-3D-k_glrlm_LowGrayLevelRunEmphasis', 'lbp-3D-k_glrlm_RunEntropy',
#         'lbp-3D-k_glrlm_RunLengthNonUniformity',
#         'lbp-3D-k_glrlm_RunLengthNonUniformityNormalized',
#         'lbp-3D-k_glrlm_RunPercentage', 'lbp-3D-k_glrlm_RunVariance',
#         'lbp-3D-k_glrlm_ShortRunEmphasis',
#         'lbp-3D-k_glrlm_ShortRunHighGrayLevelEmphasis',
#         'lbp-3D-k_glrlm_ShortRunLowGrayLevelEmphasis',
#         'lbp-3D-k_glszm_GrayLevelNonUniformity',
#         'lbp-3D-k_glszm_GrayLevelNonUniformityNormalized',
#         'lbp-3D-k_glszm_GrayLevelVariance',
#         'lbp-3D-k_glszm_HighGrayLevelZoneEmphasis',
#         'lbp-3D-k_glszm_LargeAreaEmphasis',
#         'lbp-3D-k_glszm_LargeAreaHighGrayLevelEmphasis',
#         'lbp-3D-k_glszm_LargeAreaLowGrayLevelEmphasis',
#         'lbp-3D-k_glszm_LowGrayLevelZoneEmphasis',
#         'lbp-3D-k_glszm_SizeZoneNonUniformity',
#         'lbp-3D-k_glszm_SizeZoneNonUniformityNormalized',
#         'lbp-3D-k_glszm_SmallAreaEmphasis',
#         'lbp-3D-k_glszm_SmallAreaHighGrayLevelEmphasis',
#         'lbp-3D-k_glszm_SmallAreaLowGrayLevelEmphasis',
#         'lbp-3D-k_glszm_ZoneEntropy', 'lbp-3D-k_glszm_ZonePercentage',
#         'lbp-3D-k_glszm_ZoneVariance', 'lbp-3D-k_ngtdm_Busyness',
#         'lbp-3D-k_ngtdm_Coarseness', 'lbp-3D-k_ngtdm_Complexity',
#         'lbp-3D-k_ngtdm_Contrast', 'lbp-3D-k_ngtdm_Strength', 'Transition',
#         'diagnostics_Image-original_Mean', 'diagnostics_Image-original_Maximum',
#         'diagnostics_Mask-original_VoxelNum', 'Age', 'Sex'],
#        dtype='object')}

# %%
svmModel =  m['model']
test_df = preprocess(df_test, mode='test')
m['cols']
cols = [col for col in m['cols'] if col != 'Transition']
#test_df[cols]
test_df
dt_predictions = voting_clf.predict(test_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 7
#       5 #test_df[cols]
#       6 test_df
# ----> 7 dt_predictions = voting_clf.predict(test_df)
#
# File ~/uni/DAA/.venv/lib/python3.12/site-packages/sklearn/ensemble/_voting.py:436, in VotingClassifier.predict(self, X)
#     434 check_is_fitted(self)
#     435 if self.voting == "soft":
# --> 436     maj = np.argmax(self.predict_proba(X), axis=1)
#     438 else:  # 'hard' voting
#     439     predictions = self._predict(X)
#
# File ~/uni/DAA/.venv/lib/python3.12/site-packages/sklearn/ensemble/_voting.py:477, in VotingClassifier.predict_proba(self, X)
#     463 """Compute probabilities of possible outcomes for samples in X.
#     464
#     465 Parameters
#    (...)
#     473     Weighted average probability for each class per sample.
#     474 """
#     475 check_is_fitted(self)
#     476 avg = np.average(
# --> 477     self._collect_probas(X), axis=0, weights=self._weights_not_none
#     478 )
#     479 return avg
#
# File ~/uni/DAA/.venv/lib/python3.12/site-packages/sklearn/ensemble/_voting.py:452, in VotingClassifier._collect_probas(self, X)
#     450 def _collect_probas(self, X):
#     451     """Collect results from clf.predict calls."""
# --> 452     return np.asarray([clf.predict_proba(X) for clf in self.estimators_])
#
# File ~/uni/DAA/.venv/lib/python3.12/site-packages/sklearn/svm/_base.py:864, in BaseSVC.predict_proba(self, X)
#     837 @available_if(_check_proba)
#     838 def predict_proba(self, X):
#     839     """Compute probabilities of possible outcomes for samples in X.
#     840
#     841     The model needs to have probability information computed at training
#    (...)
#     862     datasets.
#     863     """
# --> 864     X = self._validate_for_predict(X)
#     865     if self.probA_.size == 0 or self.probB_.size == 0:
#     866         raise NotFittedError(
#     867             "predict_proba is not available when fitted with probability=False"
#     868         )
#
# File ~/uni/DAA/.venv/lib/python3.12/site-packages/sklearn/svm/_base.py:613, in BaseLibSVM._validate_for_predict(self, X)
#     610 check_is_fitted(self)
#     612 if not callable(self.kernel):
# --> 613     X = validate_data(
#     614         self,
#     615         X,
#     616         accept_sparse="csr",
#     617         dtype=np.float64,
#     618         order="C",
#     619         accept_large_sparse=False,
#     620         reset=False,
#     621     )
#     623 if self._sparse and not sp.issparse(X):
#     624     X = sp.csr_matrix(X)
#
# File ~/uni/DAA/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2835 def validate_data(
#    2836     _estimator,
#    2837     /,
#    (...)
#    2843     **check_params,
#    2844 ):
#    2845     """Validate input data and set or check feature names and counts of the input.
#    2846
#    2847     This helper function should be used in an estimator that requires input
#    (...)
#    2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# File ~/uni/DAA/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2777, in _check_feature_names(estimator, X, reset)
#    2774 if not missing_names and not unexpected_names:
#    2775     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2777 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - exponential_firstorder_10Percentile
# - exponential_firstorder_90Percentile
# - exponential_firstorder_Energy
# - exponential_firstorder_Entropy
# - exponential_firstorder_InterquartileRange
# - ...

# %%
submission = pd.DataFrame(
    {'RowId': df_test.index + 1, 'Result': le.inverse_transform(dt_predictions)})

with open(f'good_submissions/customBagging.csv', 'w+') as file:
    submission.to_csv(file, index=False, sep=",")
